# %% [markdown]
# <a href="https://colab.research.google.com/github/rchamchong/DeepLearningTool/blob/main/DataFrame1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# คำสั่งเกี่ยวกับ Dataframe
#
# **import pandas as pd**

# %%
#import numpy as np
import pandas as pd
import os
from google.colab import drive

# %%
drive.mount('/content/drive')
os.chdir("/content/drive/My Drive/Colab Notebooks/DeepLearningTool/")
path=os.getcwd() #อ่าน current directory

# สร้าง pandas frame
if os.path.exists('./data/Rice1.xlsx'):
  df = pd.read_excel('./data/Rice1.xlsx')
  #print(df)
  x=df['คุณภาพดิน'].to_numpy()
  print(x)
  y=df['ผลผลิต'].to_numpy()
  print(y)
else:
  print('File does not exist.')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [  0.   0.   0. ... 100. 100. 100.]
# [4.000e+02 4.400e+02 4.500e+02 ... 6.000e+05 6.677e+05 9.000e+05]

# %%
import matplotlib.pyplot as plt

plt.figure(1,figsize=(20,6))
plt.plot(x,y,'bx')
plt.show()

# plt.figure(2,figsize=(20,6))
# plt.bar(x,y)
# plt.show()
